# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import jaccard_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import mean_absolute_error

# %%
#load the dataset
data = pd.read_csv("/content/Breast_Cancer.csv")

# %%
data
# Out:
#       Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 0      68  White        Married       T1      N1       IIA
# 1      50  White        Married       T2      N2      IIIA
# 2      58  White       Divorced       T3      N3      IIIC
# 3      58  White        Married       T1      N1       IIA
# 4      47  White        Married       T2      N1       IIB
# ...   ...    ...            ...      ...     ...       ...
# 4019   62  Other        Married       T1      N1       IIA
# 4020   56  White       Divorced       T2      N2      IIIA
# 4021   68  White        Married       T2      N1       IIB
# 4022   58  Black       Divorced       T2      N1       IIB
# 4023   46  White        Married       T2      N1       IIB
#
#                   differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 0         Poorly differentiated     3  Regional           4        Positive
# 1     Moderately differentiated     2  Regional          35        Positive
# 2     Moderately differentiated     2  Regional          63        Positive
# 3         Poorly differentiated     3  Regional          18        Positive
# 4         Poorly differentiated     3  Regional          41        Positive
# ...                         ...   ...       ...         ...             ...
# 4019  Moderately differentiated     2  Regional           9        Positive
# 4020  Moderately differentiated     2  Regional          46        Positive
# 4021  Moderately differentiated     2  Regional          22        Positive
# 4022  Moderately differentiated     2  Regional          44        Positive
# 4023  Moderately differentiated     2  Regional          30        Positive
#
#      Progesterone Status  Regional Node Examined  Reginol Node Positive  \
# 0               Positive                      24                      1
# 1               Positive                      14                      5
# 2               Positive                      14                      7
# 3               Positive                       2                      1
# 4               Positive                       3                      1
# ...                  ...                     ...                    ...
# 4019            Positive                       1                      1
# 4020            Positive                      14                      8
# 4021            Negative                      11                      3
# 4022            Positive                      11                      1
# 4023            Positive                       7                      2
#
#       Survival Months Status
# 0                  60  Alive
# 1                  62  Alive
# 2                  75  Alive
# 3                  84  Alive
# 4                  50  Alive
# ...               ...    ...
# 4019               49  Alive
# 4020               69  Alive
# 4021               69  Alive
# 4022               72  Alive
# 4023              100  Alive
#
# [4024 rows x 16 columns]

# %%
#rename columns
data.rename(columns={"Reginol Node Positive":"Regional Node Positive"}, inplace=True)
data.rename(columns={"T Stage ": "T Stage"}, inplace=True)

# %%
#datatypes of attributes
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4024 entries, 0 to 4023
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     4024 non-null   int64
#  1   Race                    4024 non-null   object
#  2   Marital Status          4024 non-null   object
#  3   T Stage                 4024 non-null   object
#  4   N Stage                 4024 non-null   object
#  5   6th Stage               4024 non-null   object
#  6   differentiate           4024 non-null   object
#  7   Grade                   4024 non-null   object
#  8   A Stage                 4024 non-null   object
#  9   Tumor Size              4024 non-null   int64
#  10  Estrogen Status         4024 non-null   object
#  11  Progesterone Status     4024 non-null   object
#  12  Regional Node Examined  4024 non-null   int64
#  13  Regional Node Positive  4024 non-null   int64
#  14  Survival Months         4024 non-null   int64
#  15  Status                  4024 non-null   object
# dtypes: int64(5), object(11)
# memory usage: 503.1+ KB

# %%
#check missing values
data.isna().any().any()
# Out:
# False

# %%
#check no of unique values in dataset
data.apply(lambda x: len(x.unique()) )
# Out:
# Age                        40
# Race                        3
# Marital Status              5
# T Stage                     4
# N Stage                     3
# 6th Stage                   5
# differentiate               4
# Grade                       4
# A Stage                     2
# Tumor Size                110
# Estrogen Status             2
# Progesterone Status         2
# Regional Node Examined     54
# Regional Node Positive     38
# Survival Months           107
# Status                      2
# dtype: int64

# %%
#Check for categorical attributes
cat_col = []
for x in data.dtypes.index:
    if data.dtypes[x] == 'object':
        cat_col.append(x)

cat_col
# Out:
# ['Race',
#  'Marital Status',
#  'T Stage',
#  'N Stage',
#  '6th Stage',
#  'differentiate',
#  'Grade',
#  'A Stage',
#  'Estrogen Status',
#  'Progesterone Status',
#  'Status']

# %%
#remove unneccesary categorical columns
data = data.drop(['Race', 'Marital Status'], axis = 1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4024 entries, 0 to 4023
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     4024 non-null   int64
#  1   T Stage                 4024 non-null   object
#  2   N Stage                 4024 non-null   object
#  3   6th Stage               4024 non-null   object
#  4   differentiate           4024 non-null   object
#  5   Grade                   4024 non-null   object
#  6   A Stage                 4024 non-null   object
#  7   Tumor Size              4024 non-null   int64
#  8   Estrogen Status         4024 non-null   object
#  9   Progesterone Status     4024 non-null   object
#  10  Regional Node Examined  4024 non-null   int64
#  11  Regional Node Positive  4024 non-null   int64
#  12  Survival Months         4024 non-null   int64
#  13  Status                  4024 non-null   object
# dtypes: int64(5), object(9)
# memory usage: 440.2+ KB

# %% [markdown]
# #GET UNIQUE VALUES

# %%
data['Age'].unique()
# Out:
# array([68, 50, 58, 47, 51, 40, 69, 46, 65, 48, 62, 61, 56, 43, 60, 57, 55,
#        63, 66, 53, 59, 54, 49, 64, 42, 37, 67, 31, 52, 33, 45, 38, 39, 36,
#        41, 44, 32, 34, 35, 30])

# %%
data['T Stage'].unique()
# Out:
# array(['T1', 'T2', 'T3', 'T4'], dtype=object)

# %%
data['N Stage'].unique()
# Out:
# array(['N1', 'N2', 'N3'], dtype=object)

# %%
data['6th Stage'].unique()
# Out:
# array(['IIA', 'IIIA', 'IIIC', 'IIB', 'IIIB'], dtype=object)

# %%
data['differentiate'].unique()
# Out:
# array(['Poorly differentiated', 'Moderately differentiated',
#        'Well differentiated', 'Undifferentiated'], dtype=object)

# %%
data['Grade'].unique()
# Out:
# array(['3', '2', '1', ' anaplastic; Grade IV'], dtype=object)

# %%
data['A Stage'].unique()
# Out:
# array(['Regional', 'Distant'], dtype=object)

# %%
data['Tumor Size'].unique()
# Out:
# array([  4,  35,  63,  18,  41,  20,   8,  30, 103,  32,  13,  59,  15,
#         19,  46,  24,  25,  29,  40,  70,  22,  50,  17,  21,  10,  27,
#         23,   5,  51,   9,  55, 120,  77,   2,  11,  12,  26,  75, 130,
#         34,  80,   3,  60,  14,  16,  45,  36,  76,  38,  49,   7,  72,
#        100,  43,  62,  37,  68,  52,  85,  57,  39,  28,  48, 110,  65,
#          6, 105, 140,  42,  31,  90, 108,  98,  47,  54,  61,  74,  33,
#          1,  87,  81,  58, 117,  44, 123, 133,  95, 107,  92,  69,  56,
#         82,  66,  78,  97,  88,  53,  83, 101,  84, 115,  73, 125, 104,
#         94,  86,  64,  96,  79,  67])

# %%
data['Estrogen Status'].unique()
# Out:
# array(['Positive', 'Negative'], dtype=object)

# %%
data['Progesterone Status'].unique()
# Out:
# array(['Positive', 'Negative'], dtype=object)

# %%
data['Regional Node Examined'].unique()
# Out:
# array([24, 14,  2,  3, 18, 11,  9, 20, 21, 13, 23, 16,  1, 22, 15,  4, 26,
#        31, 25, 10,  5,  6, 19, 12,  8, 17,  7, 49, 33, 30, 34, 28, 32, 27,
#        42, 29, 41, 39, 46, 40, 51, 44, 38, 47, 54, 36, 61, 37, 35, 43, 52,
#        45, 57, 60])

# %%
data['Regional Node Positive'].unique()
# Out:
# array([ 1,  5,  7,  2, 18, 12,  3, 14, 22, 17, 23,  4, 10,  6,  9,  8, 20,
#        16, 13, 11, 24, 27, 21, 26, 15, 28, 19, 29, 31, 46, 33, 37, 30, 35,
#        25, 32, 41, 34])

# %%
data['Survival Months'].unique()
# Out:
# array([ 60,  62,  75,  84,  50,  89,  54,  14,  70,  92,  64,  56,  38,
#         49, 105, 107,  77,  81,  78, 102,  98,  82,  86,  52,  90,  31,
#         37, 103,  42,  61,  63,  39,  59,  71,  74,  73,  91, 106,  80,
#         44,  85,  79, 104,  12,  95,  55, 101,  65,  72,  57,  87,  40,
#         25,   8,  53,  58,  24,  66,  69,  93,  94, 100,  96,  41,  67,
#         51,  13,  11,  47,  23,  45,  68,  76,  15,  16,  99,   7,  48,
#         88,  34,  97,  83,  17,   3,  22,  30,   6,  32,   9,   5,  10,
#         19,  18,  35,  27,  36,   4,  29,  33,  26,  20,  28,  43,   1,
#         46,  21,   2])

# %%
data['Status'].unique()
# Out:
# array(['Alive', 'Dead'], dtype=object)

# %% [markdown]
# #Replace catogorical values with numerical val

# %%
data["Grade"].replace({" anaplastic; Grade IV": "4"}, inplace=True)
data["Grade"] = data["Grade"].astype(int)
data["T Stage"].replace({"T1":1, "T2": 2, "T3":3, "T4": 4}, inplace=True)
data["N Stage"].replace({"N1":1, "N2": 2, "N3":3}, inplace=True)
data["6th Stage"].replace({"IIA":1, "IIB": 2, "IIIA":3, "IIIB": 4,"IIIC":5}, inplace=True)
data["differentiate"].replace({"Moderately differentiated": 2,
                            "Poorly differentiated": 1,
                            "Well differentiated": 3,
                            "Undifferentiated": 0}, inplace=True)
data["A Stage"].replace({"Regional":1, "Distant": 0}, inplace=True)
data["Estrogen Status"].replace({"Positive":1, "Negative": 0}, inplace=True)
data["Progesterone Status"].replace({"Positive":1, "Negative": 0}, inplace=True)
data["Status"].replace({"Alive":1, "Dead": 0}, inplace=True)

# %%
data
# Out:
#       Age  T Stage  N Stage  6th Stage  differentiate  Grade  A Stage  \
# 0      68        1        1          1              1      3        1
# 1      50        2        2          3              2      2        1
# 2      58        3        3          5              2      2        1
# 3      58        1        1          1              1      3        1
# 4      47        2        1          2              1      3        1
# ...   ...      ...      ...        ...            ...    ...      ...
# 4019   62        1        1          1              2      2        1
# 4020   56        2        2          3              2      2        1
# 4021   68        2        1          2              2      2        1
# 4022   58        2        1          2              2      2        1
# 4023   46        2        1          2              2      2        1
#
#       Tumor Size  Estrogen Status  Progesterone Status  \
# 0              4                1                    1
# 1             35                1                    1
# 2             63                1                    1
# 3             18                1                    1
# 4             41                1                    1
# ...          ...              ...                  ...
# 4019           9                1                    1
# 4020          46                1                    1
# 4021          22                1                    0
# 4022          44                1                    1
# 4023          30                1                    1
#
#       Regional Node Examined  Regional Node Positive  Survival Months  Status
# 0                         24                       1               60       1
# 1                         14                       5               62       1
# 2                         14                       7               75       1
# 3                          2                       1               84       1
# 4                          3                       1               50       1
# ...                      ...                     ...              ...     ...
# 4019                       1                       1               49       1
# 4020                      14                       8               69       1
# 4021                      11                       3               69       1
# 4022                      11                       1               72       1
# 4023                       7                       2              100       1
#
# [4024 rows x 14 columns]

# %% [markdown]
# # Visualize data distributions, correlations, and patterns

# %%
sns.pairplot(data, hue="Status")
plt.show()

# %%
#function to check all the features according to whether they are alive(1) or dead(0)

def statuscountplot (df,var):
    sns.countplot(data=df,x=var,hue='Status')
    sns.set(rc={'figure.figsize':(10,8)})
    plt.xticks(rotation=90)
    plt.show()

# %% [markdown]
# #plot features

# %%
dfexp=data.drop('Status',axis=1)
for i in dfexp.columns:
    statuscountplot (data,i)

# %% [markdown]
# # Statistical info

# %%
temp = data.describe()
temp.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_2e92f_row0_col0, #T_2e92f_row0_col1, #T_2e92f_row0_col2, #T_2e92f_row0_col3, #T_2e92f_row0_col4, #T_2e92f_row0_col5, #T_2e92f_row0_col6, #T_2e92f_row0_col7, #T_2e92f_row0_col8, #T_2e92f_row0_col9, #T_2e92f_row0_col10, #T_2e92f_row0_col11, #T_2e92f_row0_col12, #T_2e92f_row0_col13 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_2e92f_row1_col0, #T_2e92f_row4_col0, #T_2e92f_row5_col0, #T_2e92f_row6_col7, #T_2e92f_row7_col11 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_2e92f_row1_col1, #T_2e92f_row1_col2, #T_2e92f_row1_col3, #T_2e92f_row1_col4, #T_2e92f_row1_col5, #T_2e92f_row1_col6, #T_2e92f_row1_col8, #T_2e92f_row1_col9, #T_2e92f_row1_col10, #T_2e92f_row1_col11, #T_2e92f_row1_col13, #T_2e92f_row2_col0, #T_2e92f_row2_col1, #T_2e92f_row2_col2, #T_2e92f_row2_col3, #T_2e92f_row2_col4, #T_2e92f_row2_col5, #T_2e92f_row2_col6, #T_2e92f_row2_col8, #T_2e92f_row2_col9, #T_2e92f_row2_col10, #T_2e92f_row2_col11, #T_2e92f_row2_col13, #T_2e92f_row3_col1, #T_2e92f_row3_col2, #T_2e92f_row3_col3, #T_2e92f_row3_col4, #T_2e92f_row3_col5, #T_2e92f_row3_col6, #T_2e92f_row3_col7, #T_2e92f_row3_col8, #T_2e92f_row3_col9, #T_2e92f_row3_col10, #T_2e92f_row3_col11, #T_2e92f_row3_col12, #T_2e92f_row3_col13, #T_2e92f_row4_col1, #T_2e92f_row4_col2, #T_2e92f_row4_col3, #T_2e92f_row4_col4, #T_2e92f_row4_col5, #T_2e92f_row4_col6, #T_2e92f_row4_col7, #T_2e92f_row4_col8, #T_2e92f_row4_col9, #T_2e92f_row4_col10, #T_2e92f_row4_col11, #T_2e92f_row4_col13, #T_2e92f_row5_col1, #T_2e92f_row5_col2, #T_2e92f_row5_col3, #T_2e92f_row5_col4, #T_2e92f_row5_col5, #T_2e92f_row5_col6, #T_2e92f_row5_col8, #T_2e92f_row5_col9, #T_2e92f_row5_col10, #T_2e92f_row5_col11, #T_2e92f_row5_col13, #T_2e92f_row6_col1, #T_2e92f_row6_col2, #T_2e92f_row6_col3, #T_2e92f_row6_col4, #T_2e92f_row6_col5, #T_2e92f_row6_col6, #T_2e92f_row6_col8, #T_2e92f_row6_col9, #T_2e92f_row6_col11, #T_2e92f_row6_col13, #T_2e92f_row7_col1, #T_2e92f_row7_col2, #T_2e92f_row7_col3, #T_2e92f_row7_col4, #T_2e92f_row7_col5, #T_2e92f_row7_col6, #T_2e92f_row7_col8, #T_2e92f_row7_col9, #T_2e92f_row7_col13 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_2e92f_row1_col7, #T_2e92f_row2_col7, #T_2e92f_row2_col12, #T_2e92f_row3_col0, #T_2e92f_row5_col7, #T_2e92f_row6_col10 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_2e92f_row1_col12, #T_2e92f_row5_col12 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_2e92f_row4_col12, #T_2e92f_row6_col0, #T_2e92f_row7_col0, #T_2e92f_row7_col10 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_2e92f_row6_col12 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_2e92f_row7_col7 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_2e92f_row7_col12 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# </style>
# <table id="T_2e92f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2e92f_level0_col0" class="col_heading level0 col0" >Age</th>
#       <th id="T_2e92f_level0_col1" class="col_heading level0 col1" >T Stage</th>
#       <th id="T_2e92f_level0_col2" class="col_heading level0 col2" >N Stage</th>
#       <th id="T_2e92f_level0_col3" class="col_heading level0 col3" >6th Stage</th>
#       <th id="T_2e92f_level0_col4" class="col_heading level0 col4" >differentiate</th>
#       <th id="T_2e92f_level0_col5" class="col_heading level0 col5" >Grade</th>
#       <th id="T_2e92f_level0_col6" class="col_heading level0 col6" >A Stage</th>
#       <th id="T_2e92f_level0_col7" class="col_heading level0 col7" >Tumor Size</th>
#       <th id="T_2e92f_level0_col8" class="col_heading level0 col8" >Estrogen Status</th>
#       <th id="T_2e92f_level0_col9" class="col_heading level0 col9" >Progesterone Status</th>
#       <th id="T_2e92f_level0_col10" class="col_heading level0 col10" >Regional Node Examined</th>
#       <th id="T_2e92f_level0_col11" class="col_heading level0 col11" >Regional Node Positive</th>
#       <th id="T_2e92f_level0_col12" class="col_heading level0 col12" >Survival Months</th>
#       <th id="T_2e92f_level0_col13" class="col_heading level0 col13" >Status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e92f_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_2e92f_row0_col0" class="data row0 col0" >4024.000000</td>
#       <td id="T_2e92f_row0_col1" class="data row0 col1" >4024.000000</td>
#       <td id="T_2e92f_row0_col2" class="data row0 col2" >4024.000000</td>
#       <td id="T_2e92f_row0_col3" class="data row0 col3" >4024.000000</td>
#       <td id="T_2e92f_row0_col4" class="data row0 col4" >4024.000000</td>
#       <td id="T_2e92f_row0_col5" class="data row0 col5" >4024.000000</td>
#       <td id="T_2e92f_row0_col6" class="data row0 col6" >4024.000000</td>
#       <td id="T_2e92f_row0_col7" class="data row0 col7" >4024.000000</td>
#       <td id="T_2e92f_row0_col8" class="data row0 col8" >4024.000000</td>
#       <td id="T_2e92f_row0_col9" class="data row0 col9" >4024.000000</td>
#       <td id="T_2e92f_row0_col10" class="data row0 col10" >4024.000000</td>
#       <td id="T_2e92f_row0_col11" class="data row0 col11" >4024.000000</td>
#       <td id="T_2e92f_row0_col12" class="data row0 col12" >4024.000000</td>
#       <td id="T_2e92f_row0_col13" class="data row0 col13" >4024.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2e92f_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_2e92f_row1_col0" class="data row1 col0" >53.972167</td>
#       <td id="T_2e92f_row1_col1" class="data row1 col1" >1.784791</td>
#       <td id="T_2e92f_row1_col2" class="data row1 col2" >1.438370</td>
#       <td id="T_2e92f_row1_col3" class="data row1 col3" >2.321819</td>
#       <td id="T_2e92f_row1_col4" class="data row1 col4" >1.849404</td>
#       <td id="T_2e92f_row1_col5" class="data row1 col5" >2.150596</td>
#       <td id="T_2e92f_row1_col6" class="data row1 col6" >0.977137</td>
#       <td id="T_2e92f_row1_col7" class="data row1 col7" >30.473658</td>
#       <td id="T_2e92f_row1_col8" class="data row1 col8" >0.933151</td>
#       <td id="T_2e92f_row1_col9" class="data row1 col9" >0.826541</td>
#       <td id="T_2e92f_row1_col10" class="data row1 col10" >14.357107</td>
#       <td id="T_2e92f_row1_col11" class="data row1 col11" >4.158052</td>
#       <td id="T_2e92f_row1_col12" class="data row1 col12" >71.297962</td>
#       <td id="T_2e92f_row1_col13" class="data row1 col13" >0.846918</td>
#     </tr>
#     <tr>
#       <th id="T_2e92f_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_2e92f_row2_col0" class="data row2 col0" >8.963134</td>
#       <td id="T_2e92f_row2_col1" class="data row2 col1" >0.765531</td>
#       <td id="T_2e92f_row2_col2" class="data row2 col2" >0.693479</td>
#       <td id="T_2e92f_row2_col3" class="data row2 col3" >1.266624</td>
#       <td id="T_2e92f_row2_col4" class="data row2 col4" >0.638234</td>
#       <td id="T_2e92f_row2_col5" class="data row2 col5" >0.638234</td>
#       <td id="T_2e92f_row2_col6" class="data row2 col6" >0.149485</td>
#       <td id="T_2e92f_row2_col7" class="data row2 col7" >21.119696</td>
#       <td id="T_2e92f_row2_col8" class="data row2 col8" >0.249791</td>
#       <td id="T_2e92f_row2_col9" class="data row2 col9" >0.378691</td>
#       <td id="T_2e92f_row2_col10" class="data row2 col10" >8.099675</td>
#       <td id="T_2e92f_row2_col11" class="data row2 col11" >5.109331</td>
#       <td id="T_2e92f_row2_col12" class="data row2 col12" >22.921430</td>
#       <td id="T_2e92f_row2_col13" class="data row2 col13" >0.360111</td>
#     </tr>
#     <tr>
#       <th id="T_2e92f_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_2e92f_row3_col0" class="data row3 col0" >30.000000</td>
#       <td id="T_2e92f_row3_col1" class="data row3 col1" >1.000000</td>
#       <td id="T_2e92f_row3_col2" class="data row3 col2" >1.000000</td>
#       <td id="T_2e92f_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_2e92f_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_2e92f_row3_col5" class="data row3 col5" >1.000000</td>
#       <td id="T_2e92f_row3_col6" class="data row3

# %% [markdown]
# #Correlation between features

# %%
#correlation between features to understand which feature has the most impact on the other

correlation = data.corr().round(2)
plt.figure(figsize = (15,8))
sns.heatmap(correlation, annot = True, cmap = 'YlGnBu')
# Out:
# <Axes: >

# %% [markdown]
# #Normalization

# %%
# Feature Scaling or Normalization
scaler = StandardScaler()
data[["Age", "Tumor Size", "Regional Node Examined", "Regional Node Positive", "Survival Months"]] = scaler.fit_transform(data[["Age", "Tumor Size", "Regional Node Examined", "Regional Node Positive", "Survival Months"]])

# %% [markdown]
# #Split

# %%
#define inputs and outputs

df1= data.copy()

X = df1.drop(['Status'], axis = 1)
y = df1['Status']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %% [markdown]
# #Using random forest classifier

# %%
rfmodel=RandomForestClassifier(n_estimators=600)

# %%
rfmodel.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=600)

# %%
y_pred=rfmodel.predict(X_test)

# %% [markdown]
# #Cross validation

# %%
# Specify the number of folds for cross-validation
n_folds = 5
# Create a KFold cross-validation object
kf = KFold(n_splits=n_folds, shuffle=True, random_state=42)

# Perform cross-validation and collect scores
cross_val_scores = cross_val_score(rfmodel, X, y, cv=kf, scoring='accuracy')

# Print the accuracy scores for each fold
for fold, score in enumerate(cross_val_scores, start=1):
    print(f'Fold {fold}: {score:.4f}')

# Calculate the average accuracy
average_accuracy = cross_val_scores.mean()
print(f'Average Accuracy: {average_accuracy:.4f}')
# Out:
# Fold 1: 0.9130
# Fold 2: 0.9118
# Fold 3: 0.9130
# Fold 4: 0.8932
# Fold 5: 0.8930
# Average Accuracy: 0.9048

# %% [markdown]
# # Create a confusion matrix

# %%
confusion = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", confusion)
# Out:
# Confusion Matrix:
#  [[ 53  53]
#  [ 15 684]]

# %% [markdown]
# #Get the accuracy values

# %%
print('Accuracy score: ',accuracy_score(y_test,y_pred))
print('Recall score: ',recall_score(y_test,y_pred))
print('Jaccard score: ',jaccard_score(y_test,y_pred))
print('f1 score: ',f1_score(y_test,y_pred))
print('Precision score: ',precision_score(y_test,y_pred))
# Out:
# Accuracy score:  0.915527950310559
# Recall score:  0.9785407725321889
# Jaccard score:  0.9095744680851063
# f1 score:  0.9526462395543175
# Precision score:  0.9280868385345997
